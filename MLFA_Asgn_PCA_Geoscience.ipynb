# %%
# !pip install netCDF4
# !pip install basemap

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # Loading the Dataset, Preprocessing and Visualisation

# %%
# Load dataset using NetCDF4
from netCDF4 import Dataset
# fh = Dataset('/content/drive/MyDrive/Colab Notebooks/sst.mon.mean.nc')
fh = Dataset('sst.mon.mean.nc', mode='r')

# %%
# Separate lon,lat,sst and time in different variables
lon = fh.variables['lon'][:]
lat = fh.variables['lat'][:]
sst = fh.variables['sst'][:]
time = fh.variables['time'][:]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import numpy as np
import seaborn as sns


def plot_map(heading, lon, lat, data):
    m = Basemap(
        projection='cyl', resolution='l',
        llcrnrlat=np.min(fh.variables['lat'][:]), urcrnrlat=np.max(fh.variables['lat'][:]),
        llcrnrlon=np.min(fh.variables['lon'][:]), urcrnrlon=np.max(fh.variables['lon'][:]),
    )
    m.drawcoastlines()
    # plt.show()
    lons, lats = np.meshgrid(lon, lat)
    x, y = m(lons, lats)

    m.drawcoastlines()
    levels = np.linspace(min(np.unique(data)), max(np.unique(data)), 30)
    # levels=[-30,-20,-12,-9,-6,-2,-1,+1,+2,+6,+9,+12,+20,+30]
    temp = m.contourf(x, y, data, levels=levels, cmap='seismic')
    cb = m.colorbar(temp, "bottom", size="15%", pad="10%")
    # m.drawcoastlines()
    plt.title(heading)
    cb.set_label('sst')
    plt.show()
    plt.clf()

# %% [markdown]
# ### Mean SST plots

# %%
plot_map(
    "Mean SST over the years",
    lon, lat,
    np.mean(sst, axis=0)
)

# %%
# Plot the mean sst over the years for the selected region on Basemap
plot_map(
    "Mean Nino 3.4 SST over the years",
    lon[170:290], lat[84:96],
    np.mean(sst[:, 84:96, 170:290], axis=0)
)

# %% [markdown]
# # Preprocessing

# %%
# SST anomaly for the Nino 3.4 region
nino_3_4_sst = sst[:, 84:96, 170:290]
nino_3_4_sst_anomaly = nino_3_4_sst - nino_3_4_sst.mean()

# %%
# Mean Monthly Anomaly
mean_nino_3_4_sst_anomaly_monthly = np.mean(nino_3_4_sst_anomaly, axis=(1, 2))

# Mean Yearly Anomaly
n_months = mean_nino_3_4_sst_anomaly_monthly.shape[0]
mean_nino_3_4_sst_anomaly_yearly = np.split(
    mean_nino_3_4_sst_anomaly_monthly[:0-n_months % 12],
    n_months//12,
)
mean_nino_3_4_sst_anomaly_yearly = [
    year.mean() for year in mean_nino_3_4_sst_anomaly_yearly]
mean_nino_3_4_sst_anomaly_yearly = np.array(mean_nino_3_4_sst_anomaly_yearly)

# Mean 3 monthly Anomaly
mean_nino_3_4_sst_anomaly_trimonthly = np.split(
    mean_nino_3_4_sst_anomaly_monthly[:0-n_months % 3],
    n_months//3,
)
mean_nino_3_4_sst_anomaly_trimonthly = [
    tri.mean() for tri in mean_nino_3_4_sst_anomaly_trimonthly]
mean_nino_3_4_sst_anomaly_trimonthly = np.array(
    mean_nino_3_4_sst_anomaly_trimonthly)

# %%
print(mean_nino_3_4_sst_anomaly_monthly.shape)
print(mean_nino_3_4_sst_anomaly_trimonthly.shape)
print(mean_nino_3_4_sst_anomaly_yearly.shape)
# Out:
# (1586,)
# (528,)
# (132,)

# %% [markdown]
# ### Visualising averaged SST Anomaly

# %%
plt.figure(figsize=(8, 2), dpi=200)
plt.plot(mean_nino_3_4_sst_anomaly_monthly)
plt.title("Montly Mean Nino 3.4 SST anomaly")
# Out:
# Text(0.5, 1.0, 'Montly Mean Nino 3.4 SST anomaly')

# %%
plt.figure(figsize=(8, 2), dpi=200)
plt.plot(mean_nino_3_4_sst_anomaly_trimonthly)
plt.title("3-Monthly Mean Nino 3.4 SST anomaly")
# Out:
# Text(0.5, 1.0, '3-Monthly Mean Nino 3.4 SST anomaly')

# %%
plt.figure(figsize=(8, 2), dpi=200)
sns.lineplot(
    x=range(1891, 1891+mean_nino_3_4_sst_anomaly_yearly.size),
    y=mean_nino_3_4_sst_anomaly_yearly
)
plt.title("Annual Mean Nino 3.4 SST anomaly")
# Out:
# Text(0.5, 1.0, 'Annual Mean Nino 3.4 SST anomaly')

# %% [markdown]
# # Trainning

# %%
def prepare_model_input(data):
    ENSO_label = []
    dim = data.shape
    # mean_sst_anomaly_yearly = np.split(data[:0-dim[0] % 12], dim[0]//12, axis=0)
    # mean_sst_anomaly_yearly = [np.mean(a, axis=0)
    #                            for a in mean_sst_anomaly_yearly]
    # mean_sst_anomaly_yearly = np.stack(mean_sst_anomaly_yearly)

    # mean_sst_anomaly_yearly_flattened = mean_sst_anomaly_yearly.reshape(
    #     (dim[0]//12, -1))
    sst_anomaly_trimonthly = data - data.mean()
    sst_anomaly_trimonthly = np.split(data[:0-dim[0] % 3], dim[0]//3, axis=0)
    sst_anomaly_trimonthly = [np.mean(tri, axis=0)
                              for tri in sst_anomaly_trimonthly]
    sst_anomaly_trimonthly = np.stack(sst_anomaly_trimonthly)

    sst_anomaly_trimontly_flat = np.reshape(
        sst_anomaly_trimonthly,
        (dim[0]//3, -1)
    )

    for i in mean_nino_3_4_sst_anomaly_trimonthly:
        if i > 0:
            ENSO_label.append('El-nino')
        else:
            ENSO_label.append('La-nina')

    # return (mean_sst_anomaly_yearly, np.array(ENSO_label))
    return (sst_anomaly_trimontly_flat, np.array(ENSO_label))

# %% [markdown]
# ### Preparing the Trainning and Testing Data

# %%
X, y = prepare_model_input(sst)

# %%
print(X.shape)
print(y.shape)
# Out:
# (528, 64800)
# (528,)

# %%
import numpy.ma as ma
X = ma.getdata(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3)

enso_train, y_train_idx = np.unique(y_train, return_inverse=True)
enso_test, y_test_idx = np.unique(y_test, return_inverse=True)

# %%
# Plot mean training and testing set on map
plot_map(
    "Mean of Training Data",
    lon, lat,
    np.mean(X_train.reshape((X_train.shape[0], 180, 360)), axis=0)
)

# %%
plot_map(
    "Mean of Training Data",
    lon, lat,
    np.mean(X_test.reshape((X_test.shape[0], 180, 360)), axis=0)
)

# %%
X_train.shape
# Out:
# (352, 64800)

# %% [markdown]
# ### Implementing PCA

# %%
from sklearn.decomposition import PCA
n_pca = 150
pca = PCA(n_components=n_pca).fit(X)

# %%
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
X_train_pca.shape
# Out:
# (352, 150)

# %%
# Create a device variable which will be used to shift model and data to GPU if available
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
import torch.nn as nn


class ANeuralNet(nn.Module):
    def __init__(self, in_size: int, layers: list, out_size: int) -> None:
        super().__init__()

        all_layers = []
        n = in_size
        for i in layers:
            all_layers.append(nn.Linear(n, i))
            all_layers.append(nn.ReLU(inplace=True))
            n = i
        all_layers.append(nn.Linear(layers[-1], out_size))
        self.layers = nn.Sequential(*all_layers)

    def forward(self, x):
        return self.layers(x)


def prepare_batch(b_size):
    from torch.utils.data import TensorDataset, DataLoader

    X_train_tensor = torch.tensor(X_train_pca, dtype=torch.float)
    y_train_tensor = torch.tensor(y_train_idx, dtype=torch.long)

    X_test_tensor = torch.tensor(X_test_pca, dtype=torch.float)
    y_test_tensor = torch.tensor(y_test_idx, dtype=torch.long)

    dataset_train = TensorDataset(X_train_tensor, y_train_tensor)
    dataset_test = TensorDataset(X_test_tensor, y_test_tensor)

    train_loader = DataLoader(dataset_train, batch_size=b_size, shuffle=False)
    test_loader = DataLoader(dataset_test, batch_size=b_size, shuffle=False)

    return (train_loader, test_loader)


def trainning_session(epochs: int, batch_size: int, learn_rate: float, optim):
    torch.manual_seed(0)
    model = ANeuralNet(n_pca, [100, 80, 40, 20, 10], 2)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim(model.parameters(), lr=learn_rate)
    # optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

    n_train = X_train_pca.shape[0]
    n_test = X_test_pca.shape[0]
    e = epochs
    train_loader, test_loader = prepare_batch(batch_size)

    train_losses = []
    test_losses = []
    train_accuracy = []
    test_accuracy = []

    for i in range(e):
        trn_corr = 0
        tst_corr = 0

        for b, (X_train, y_train) in enumerate(train_loader):
            y_pred = model(X_train)
            loss = criterion(y_pred, y_train)

            predicted = torch.max(y_pred.data, 1)[1]
            batch_corr = (predicted == y_train).sum()
            trn_corr += batch_corr

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        train_losses.append(loss.item())
        train_accuracy.append(trn_corr*100/n_train)

        with torch.no_grad():
            for b, (X_test, y_test) in enumerate(test_loader):
                y_val = model(X_test)
                predicted = torch.max(y_val.data, 1)[1]
                tst_corr += (predicted == y_test).sum()

        loss = criterion(y_val, y_test)
        test_losses.append(loss.item())
        test_accuracy.append(tst_corr*100/n_test)

        if (i+1)%50 == 0:
            print(
                f'epoch: {i+1}\ttrain loss: {train_losses[i]:.3f} \ttrain accuracy: {train_accuracy[i]:2.3f}%')
            print(
                f"\t\ttest loss:  {test_losses[i]:.3f} \ttest accuracy:  {test_accuracy[i]:2.3f}%\n")

    return (model, train_losses, test_losses, train_accuracy, test_accuracy)

# %% [markdown]
# ### Tranning the NN

# %%
model, train_losses, test_losses, train_accuracy, test_accuracy = trainning_session(
    epochs=500,
    batch_size=50,
    learn_rate=0.001,
    optim=torch.optim.SGD
)
# Out:
# epoch: 50	train loss: 0.689 	train accuracy: 61.648%
# 		test loss:  0.733 	test accuracy:  61.932%
#
# epoch: 100	train loss: 0.292 	train accuracy: 76.989%
# 		test loss:  0.631 	test accuracy:  77.273%
#
# epoch: 150	train loss: 0.061 	train accuracy: 85.795%
# 		test loss:  0.522 	test accuracy:  85.795%
#
# epoch: 200	train loss: 0.025 	train accuracy: 89.205%
# 		test loss:  0.407 	test accuracy:  89.205%
#
# epoch: 250	train loss: 0.015 	train accuracy: 93.750%
# 		test loss:  0.303 	test accuracy:  92.045%
#
# epoch: 300	train loss: 0.010 	train accuracy: 96.023%
# 		test loss:  0.229 	test accuracy:  92.614%
#
# epoch: 350	train loss: 0.006 	train accuracy: 97.443%
# 		test loss:  0.174 	test accuracy:  92.614%
#
# epoch: 400	train loss: 0.004 	train accuracy: 98.580%
# 		test loss:  0.133 	test accuracy:  93.182%
#
# epoch: 450	train loss: 0.002 	train accuracy: 99.148%
# 		test loss:  0.101 	test accuracy:  93.750%
#
# epoch: 500	train loss: 0.001 	train accuracy: 99.716%
# 		test loss:  0.079 	test accuracy:  94.318%

# %% [markdown]
# # Results

# %%
plt.figure(figsize=(8, 4), dpi=100)
plt.plot(train_losses)
plt.plot(test_losses)
plt.legend(["train loss", "test loss"])

# %%
plt.figure(figsize=(8, 4), dpi=100)
plt.plot(train_accuracy)
plt.plot(test_accuracy)
plt.legend(["train accuracy", "test accuracy"])

# %% [markdown]
# ### **Grid** **Search**

# %%
batch_sizes = [16,32,64,128]
learning_rates = [0.001,0.002,0.003, 0.01, 0.02, 0.03]
optimizers = [torch.optim.Adam, torch.optim.SGD]

# %%
max_acc = 0.0
chosen_model = None
max_id = None

# %%
for n_batch in batch_sizes:
    for learning_rate in learning_rates:
        for optimizer in optimizers:
            model, train_losses, test_losses, train_accuracy, test_accuracy = trainning_session(
            epochs = 500,
            batch_size= n_batch,
            learn_rate = learning_rate, 
            optim = optimizer
            )

            if test_accuracy[-1] > max_acc:
                max_acc = test_accuracy[-1]
                chosen_model = model
                max_id = [n_batch, learning_rate, optimizer]
# Out:
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.475 	test accuracy:  93.750%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.498 	test accuracy:  93.750%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.523 	test accuracy:  93.750%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.543 	test accuracy:  93.750%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.559 	test accuracy:  93.750%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.570 	test accuracy:  94.318%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.585 	test accuracy:  94.318%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.601 	test accuracy:  94.318%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.613 	test accuracy:  94.318%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.644 	test accuracy:  94.318%
#
# epoch: 50	train loss: 0.360 	train accuracy: 82.102%
# 		test loss:  0.562 	test accuracy:  80.682%
#
# epoch: 100	train loss: 0.125 	train accuracy: 95.170%
# 		test loss:  0.232 	test accuracy:  93.182%
#
# epoch: 150	train loss: 0.042 	train accuracy: 98.580%
# 		test loss:  0.110 	test accuracy:  93.182%
#
# epoch: 200	train loss: 0.014 	train accuracy: 99.432%
# 		test loss:  0.059 	test accuracy:  93.750%
#
# epoch: 250	train loss: 0.008 	train accuracy: 100.000%
# 		test loss:  0.030 	test accuracy:  94.318%
#
# epoch: 300	train loss: 0.004 	train accuracy: 100.000%
# 		test loss:  0.022 	test accuracy:  94.318%
#
# epoch: 350	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.018 	test accuracy:  94.318%
#
# epoch: 400	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.016 	test accuracy:  94.318%
#
# epoch: 450	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.015 	test accuracy:  94.318%
#
# epoch: 500	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.014 	test accuracy:  94.318%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.378 	test accuracy:  92.614%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.384 	test accuracy:  93.182%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.378 	test accuracy:  93.182%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.376 	test accuracy:  93.182%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.377 	test accuracy:  93.182%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.379 	test accuracy:  93.182%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.382 	test accuracy:  93.182%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.385 	test accuracy:  93.182%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.390 	test accuracy:  93.182%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.392 	test accuracy:  93.182%
#
# epoch: 50	train loss: 0.144 	train accuracy: 94.602%
# 		test loss:  0.238 	test accuracy:  93.182%
#
# epoch: 100	train loss: 0.019 	train accuracy: 99.432%
# 		test loss:  0.074 	test accuracy:  93.182%
#
# epoch: 150	train loss: 0.006 	train accuracy: 100.000%
# 		test loss:  0.022 	test accuracy:  93.750%
#
# epoch: 200	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.012 	test accuracy:  94.318%
#
# epoch: 250	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.010 	test accuracy:  94.318%
#
# epoch: 300	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.009 	test accuracy:  94.886%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.008 	test accuracy:  94.886%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.007 	test accuracy:  94.886%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.007 	test accuracy:  94.886%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.007 	test accuracy:  94.886%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.390 	test accuracy:  93.750%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.453 	test accuracy:  93.750%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.493 	test accuracy:  93.750%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.524 	test accuracy:  93.750%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.549 	test accuracy:  93.750%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.571 	test accuracy:  93.750%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.591 	test accuracy:  93.750%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.609 	test accuracy:  93.750%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.625 	test accuracy:  93.750%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.640 	test accuracy:  93.750%
#
# epoch: 50	train loss: 0.066 	train accuracy: 97.443%
# 		test loss:  0.170 	test accuracy:  92.614%
#
# epoch: 100	train loss: 0.005 	train accuracy: 100.000%
# 		test loss:  0.038 	test accuracy:  94.886%
#
# epoch: 150	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.009 	test accuracy:  94.886%
#
# epoch: 200	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.006 	test accuracy:  95.455%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.005 	test accuracy:  95.455%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.004 	test accuracy:  95.455%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.004 	test accuracy:  95.455%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.003 	test accuracy:  95.455%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.003 	test accuracy:  95.455%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.003 	test accuracy:  95.455%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.472 	test accuracy:  92.614%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.641 	test accuracy:  92.614%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.746 	test accuracy:  92.614%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.835 	test accuracy:  92.614%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.916 	test accuracy:  92.614%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.982 	test accuracy:  92.614%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.042 	test accuracy:  92.614%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.121 	test accuracy:  92.614%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.168 	test accuracy:  92.614%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.284 	test accuracy:  92.614%
#
# epoch: 50	train loss: 0.062 	train accuracy: 97.727%
# 		test loss:  0.135 	test accuracy:  95.455%
#
# epoch: 100	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.020 	test accuracy:  97.159%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.012 	test accuracy:  97.159%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.011 	test accuracy:  97.159%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.010 	test accuracy:  97.159%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.009 	test accuracy:  97.159%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.009 	test accuracy:  97.159%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.008 	test accuracy:  97.159%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.008 	test accuracy:  97.159%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.008 	test accuracy:  97.159%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.995 	test accuracy:  90.909%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  3.336 	test accuracy:  92.045%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  3.547 	test accuracy:  92.045%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  3.719 	test accuracy:  91.477%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  3.870 	test accuracy:  91.477%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  4.095 	test accuracy:  92.045%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  4.247 	test accuracy:  92.045%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  4.386 	test accuracy:  92.045%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  4.518 	test accuracy:  91.477%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  4.644 	test accuracy:  90.909%
#
# epoch: 50	train loss: 0.303 	train accuracy: 97.727%
# 		test loss:  0.259 	test accuracy:  90.909%
#
# epoch: 100	train loss: 0.005 	train accuracy: 99.716%
# 		test loss:  0.186 	test accuracy:  96.023%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.193 	test accuracy:  96.023%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.209 	test accuracy:  96.023%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.224 	test accuracy:  96.023%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.233 	test accuracy:  96.023%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.244 	test accuracy:  96.023%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.252 	test accuracy:  96.023%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.256 	test accuracy:  96.023%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.262 	test accuracy:  96.023%
#
# epoch: 50	train loss: 0.693 	train accuracy: 44.602%
# 		test loss:  0.694 	test accuracy:  47.727%
#
# epoch: 100	train loss: 0.693 	train accuracy: 44.602%
# 		test loss:  0.694 	test accuracy:  47.727%
#
# epoch: 150	train loss: 0.693 	train accuracy: 44.602%
# 		test loss:  0.694 	test accuracy:  47.727%
#
# epoch: 200	train loss: 0.693 	train accuracy: 44.602%
# 		test loss:  0.694 	test accuracy:  47.727%
#
# epoch: 250	train loss: 0.693 	train accuracy: 44.602%
# 		test loss:  0.694 	test accuracy:  47.727%
#
# epoch: 300	train loss: 0.693 	train accuracy: 44.602%
# 		test loss:  0.694 	test accuracy:  47.727%
#
# epoch: 350	train loss: 0.693 	train accuracy: 44.602%
# 		test loss:  0.694 	test accuracy:  47.727%
#
# epoch: 400	train loss: 0.693 	train accuracy: 44.602%
# 		test loss:  0.694 	test accuracy:  47.727%
#
# epoch: 450	train loss: 0.693 	train accuracy: 44.602%
# 		test loss:  0.694 	test accuracy:  47.727%
#
# epoch: 500	train loss: 0.693 	train accuracy: 44.602%
# 		test loss:  0.694 	test accuracy:  47.727%
#
# epoch: 50	train loss: 0.125 	train accuracy: 98.864%
# 		test loss:  0.057 	test accuracy:  96.023%
#
# epoch: 100	train loss: 0.006 	train accuracy: 99.716%
# 		test loss:  0.315 	test accuracy:  95.455%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.264 	test accuracy:  95.455%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.292 	test accuracy:  95.455%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.308 	test accuracy:  95.455%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.320 	test accuracy:  95.455%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.327 	test accuracy:  95.455%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.334 	test accuracy:  95.455%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.343 	test accuracy:  95.455%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.350 	test accuracy:  95.455%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.066 	test accuracy:  93.750%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.063 	test accuracy:  93.750%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.069 	test accuracy:  93.750%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.073 	test accuracy:  93.750%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.075 	test accuracy:  93.750%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.079 	test accuracy:  93.750%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.081 	test accuracy:  93.750%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.084 	test accuracy:  93.750%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.089 	test accuracy:  93.750%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.093 	test accuracy:  93.750%
#
# epoch: 50	train loss: 0.583 	train accuracy: 64.205%
# 		test loss:  0.683 	test accuracy:  65.909%
#
# epoch: 100	train loss: 0.466 	train accuracy: 82.670%
# 		test loss:  0.569 	test accuracy:  80.682%
#
# epoch: 150	train loss: 0.377 	train accuracy: 88.636%
# 		test loss:  0.367 	test accuracy:  88.068%
#
# epoch: 200	train loss: 0.317 	train accuracy: 95.170%
# 		test loss:  0.215 	test accuracy:  93.750%
#
# epoch: 250	train loss: 0.267 	train accuracy: 97.159%
# 		test loss:  0.147 	test accuracy:  93.182%
#
# epoch: 300	train loss: 0.222 	train accuracy: 99.148%
# 		test loss:  0.095 	test accuracy:  93.182%
#
# epoch: 350	train loss: 0.176 	train accuracy: 99.432%
# 		test loss:  0.066 	test accuracy:  94.318%
#
# epoch: 400	train loss: 0.113 	train accuracy: 99.432%
# 		test loss:  0.053 	test accuracy:  94.318%
#
# epoch: 450	train loss: 0.049 	train accuracy: 99.716%
# 		test loss:  0.041 	test accuracy:  94.318%
#
# epoch: 500	train loss: 0.028 	train accuracy: 100.000%
# 		test loss:  0.035 	test accuracy:  94.318%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.051 	test accuracy:  95.455%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.032 	test accuracy:  95.455%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.036 	test accuracy:  95.455%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.034 	test accuracy:  96.023%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.030 	test accuracy:  96.023%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.027 	test accuracy:  95.455%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.025 	test accuracy:  95.455%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.023 	test accuracy:  94.886%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.022 	test accuracy:  94.886%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.021 	test accuracy:  94.886%
#
# epoch: 50	train loss: 0.468 	train accuracy: 82.102%
# 		test loss:  0.564 	test accuracy:  80.682%
#
# epoch: 100	train loss: 0.326 	train accuracy: 94.602%
# 		test loss:  0.235 	test accuracy:  94.318%
#
# epoch: 150	train loss: 0.223 	train accuracy: 98.580%
# 		test loss:  0.110 	test accuracy:  92.045%
#
# epoch: 200	train loss: 0.123 	train accuracy: 99.432%
# 		test loss:  0.053 	test accuracy:  93.750%
#
# epoch: 250	train loss: 0.028 	train accuracy: 100.000%
# 		test loss:  0.028 	test accuracy:  94.318%
#
# epoch: 300	train loss: 0.013 	train accuracy: 100.000%
# 		test loss:  0.022 	test accuracy:  94.318%
#
# epoch: 350	train loss: 0.008 	train accuracy: 100.000%
# 		test loss:  0.020 	test accuracy:  94.318%
#
# epoch: 400	train loss: 0.005 	train accuracy: 100.000%
# 		test loss:  0.018 	test accuracy:  94.886%
#
# epoch: 450	train loss: 0.004 	train accuracy: 100.000%
# 		test loss:  0.017 	test accuracy:  94.886%
#
# epoch: 500	train loss: 0.003 	train accuracy: 100.000%
# 		test loss:  0.017 	test accuracy:  94.886%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.280 	test accuracy:  94.318%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.298 	test accuracy:  94.318%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.385 	test accuracy:  94.318%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.378 	test accuracy:  94.318%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.380 	test accuracy:  94.318%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.382 	test accuracy:  94.318%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.383 	test accuracy:  94.318%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.385 	test accuracy:  94.318%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.384 	test accuracy:  94.318%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.389 	test accuracy:  94.318%
#
# epoch: 50	train loss: 0.389 	train accuracy: 87.500%
# 		test loss:  0.361 	test accuracy:  89.205%
#
# epoch: 100	train loss: 0.230 	train accuracy: 98.295%
# 		test loss:  0.128 	test accuracy:  92.045%
#
# epoch: 150	train loss: 0.046 	train accuracy: 100.000%
# 		test loss:  0.044 	test accuracy:  94.886%
#
# epoch: 200	train loss: 0.012 	train accuracy: 100.000%
# 		test loss:  0.018 	test accuracy:  94.318%
#
# epoch: 250	train loss: 0.005 	train accuracy: 100.000%
# 		test loss:  0.013 	test accuracy:  94.886%
#
# epoch: 300	train loss: 0.003 	train accuracy: 100.000%
# 		test loss:  0.011 	test accuracy:  94.886%
#
# epoch: 350	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.010 	test accuracy:  94.886%
#
# epoch: 400	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.010 	test accuracy:  94.886%
#
# epoch: 450	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.009 	test accuracy:  94.886%
#
# epoch: 500	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.009 	test accuracy:  94.886%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.040 	test accuracy:  93.182%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.115 	test accuracy:  92.614%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.168 	test accuracy:  92.614%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.211 	test accuracy:  92.614%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.247 	test accuracy:  92.614%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.280 	test accuracy:  92.614%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.310 	test accuracy:  92.614%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.337 	test accuracy:  92.614%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.363 	test accuracy:  92.614%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.388 	test accuracy:  92.614%
#
# epoch: 50	train loss: 0.126 	train accuracy: 98.864%
# 		test loss:  0.177 	test accuracy:  93.750%
#
# epoch: 100	train loss: 0.009 	train accuracy: 100.000%
# 		test loss:  0.027 	test accuracy:  95.455%
#
# epoch: 150	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.007 	test accuracy:  96.023%
#
# epoch: 200	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.006 	test accuracy:  96.023%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.005 	test accuracy:  96.591%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.005 	test accuracy:  96.023%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.004 	test accuracy:  96.023%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.004 	test accuracy:  96.023%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.004 	test accuracy:  96.023%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.004 	test accuracy:  96.023%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.645 	test accuracy:  93.182%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.654 	test accuracy:  93.182%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.665 	test accuracy:  93.182%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.678 	test accuracy:  93.182%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.691 	test accuracy:  93.182%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.706 	test accuracy:  93.182%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.722 	test accuracy:  93.182%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.738 	test accuracy:  93.182%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.756 	test accuracy:  93.182%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  2.774 	test accuracy:  93.182%
#
# epoch: 50	train loss: 0.144 	train accuracy: 96.875%
# 		test loss:  0.090 	test accuracy:  94.886%
#
# epoch: 100	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.124 	test accuracy:  95.455%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.077 	test accuracy:  95.455%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.072 	test accuracy:  95.455%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.070 	test accuracy:  94.886%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.068 	test accuracy:  94.886%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.067 	test accuracy:  94.886%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.068 	test accuracy:  94.886%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.069 	test accuracy:  94.886%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.070 	test accuracy:  94.886%
#
# epoch: 50	train loss: 0.487 	train accuracy: 67.614%
# 		test loss:  0.515 	test accuracy:  65.909%
#
# epoch: 100	train loss: 0.487 	train accuracy: 67.614%
# 		test loss:  0.515 	test accuracy:  65.909%
#
# epoch: 150	train loss: 0.487 	train accuracy: 67.614%
# 		test loss:  0.515 	test accuracy:  65.909%
#
# epoch: 200	train loss: 0.487 	train accuracy: 67.614%
# 		test loss:  0.515 	test accuracy:  65.909%
#
# epoch: 250	train loss: 0.487 	train accuracy: 67.614%
# 		test loss:  0.515 	test accuracy:  65.909%
#
# epoch: 300	train loss: 0.487 	train accuracy: 67.614%
# 		test loss:  0.515 	test accuracy:  65.909%
#
# epoch: 350	train loss: 0.487 	train accuracy: 67.614%
# 		test loss:  0.515 	test accuracy:  65.909%
#
# epoch: 400	train loss: 0.487 	train accuracy: 67.614%
# 		test loss:  0.515 	test accuracy:  65.909%
#
# epoch: 450	train loss: 0.487 	train accuracy: 67.614%
# 		test loss:  0.515 	test accuracy:  65.909%
#
# epoch: 500	train loss: 0.487 	train accuracy: 67.614%
# 		test loss:  0.515 	test accuracy:  65.909%
#
# epoch: 50	train loss: 0.252 	train accuracy: 98.011%
# 		test loss:  0.119 	test accuracy:  86.932%
#
# epoch: 100	train loss: 0.015 	train accuracy: 98.864%
# 		test loss:  0.082 	test accuracy:  95.455%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.027 	test accuracy:  96.591%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.024 	test accuracy:  97.159%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.023 	test accuracy:  97.159%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.022 	test accuracy:  97.159%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.021 	test accuracy:  97.159%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.020 	test accuracy:  97.159%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.019 	test accuracy:  97.159%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.018 	test accuracy:  97.159%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.060 	test accuracy:  93.750%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.058 	test accuracy:  94.318%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.060 	test accuracy:  94.318%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.065 	test accuracy:  94.318%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.067 	test accuracy:  93.750%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.069 	test accuracy:  93.750%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.072 	test accuracy:  93.750%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.074 	test accuracy:  93.750%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.075 	test accuracy:  93.750%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.075 	test accuracy:  93.750%
#
# epoch: 50	train loss: 0.617 	train accuracy: 54.830%
# 		test loss:  0.642 	test accuracy:  53.409%
#
# epoch: 100	train loss: 0.566 	train accuracy: 70.455%
# 		test loss:  0.600 	test accuracy:  71.591%
#
# epoch: 150	train loss: 0.499 	train accuracy: 77.273%
# 		test loss:  0.531 	test accuracy:  77.273%
#
# epoch: 200	train loss: 0.416 	train accuracy: 84.943%
# 		test loss:  0.432 	test accuracy:  83.523%
#
# epoch: 250	train loss: 0.356 	train accuracy: 86.932%
# 		test loss:  0.343 	test accuracy:  89.205%
#
# epoch: 300	train loss: 0.311 	train accuracy: 90.625%
# 		test loss:  0.280 	test accuracy:  90.909%
#
# epoch: 350	train loss: 0.260 	train accuracy: 94.886%
# 		test loss:  0.224 	test accuracy:  92.614%
#
# epoch: 400	train loss: 0.223 	train accuracy: 96.023%
# 		test loss:  0.186 	test accuracy:  93.750%
#
# epoch: 450	train loss: 0.190 	train accuracy: 97.159%
# 		test loss:  0.155 	test accuracy:  93.750%
#
# epoch: 500	train loss: 0.160 	train accuracy: 98.295%
# 		test loss:  0.128 	test accuracy:  93.750%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.092 	test accuracy:  93.750%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.089 	test accuracy:  93.182%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.084 	test accuracy:  93.182%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.080 	test accuracy:  93.182%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.078 	test accuracy:  93.182%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.079 	test accuracy:  93.182%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.079 	test accuracy:  93.182%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.080 	test accuracy:  93.182%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.082 	test accuracy:  93.182%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.082 	test accuracy:  93.750%
#
# epoch: 50	train loss: 0.567 	train accuracy: 69.602%
# 		test loss:  0.600 	test accuracy:  71.591%
#
# epoch: 100	train loss: 0.417 	train accuracy: 84.943%
# 		test loss:  0.433 	test accuracy:  83.523%
#
# epoch: 150	train loss: 0.312 	train accuracy: 90.625%
# 		test loss:  0.279 	test accuracy:  90.909%
#
# epoch: 200	train loss: 0.226 	train accuracy: 95.455%
# 		test loss:  0.187 	test accuracy:  93.750%
#
# epoch: 250	train loss: 0.163 	train accuracy: 97.727%
# 		test loss:  0.130 	test accuracy:  93.182%
#
# epoch: 300	train loss: 0.107 	train accuracy: 99.148%
# 		test loss:  0.091 	test accuracy:  93.750%
#
# epoch: 350	train loss: 0.036 	train accuracy: 100.000%
# 		test loss:  0.064 	test accuracy:  94.318%
#
# epoch: 400	train loss: 0.017 	train accuracy: 100.000%
# 		test loss:  0.049 	test accuracy:  94.318%
#
# epoch: 450	train loss: 0.011 	train accuracy: 100.000%
# 		test loss:  0.041 	test accuracy:  94.318%
#
# epoch: 500	train loss: 0.008 	train accuracy: 100.000%
# 		test loss:  0.036 	test accuracy:  94.318%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.141 	test accuracy:  93.182%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.148 	test accuracy:  93.182%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.152 	test accuracy:  93.182%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.153 	test accuracy:  93.182%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.154 	test accuracy:  93.182%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.155 	test accuracy:  93.182%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.156 	test accuracy:  93.182%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.158 	test accuracy:  93.182%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.160 	test accuracy:  93.182%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.161 	test accuracy:  93.182%
#
# epoch: 50	train loss: 0.502 	train accuracy: 76.989%
# 		test loss:  0.533 	test accuracy:  76.705%
#
# epoch: 100	train loss: 0.317 	train accuracy: 90.341%
# 		test loss:  0.285 	test accuracy:  90.341%
#
# epoch: 150	train loss: 0.194 	train accuracy: 96.591%
# 		test loss:  0.159 	test accuracy:  93.182%
#
# epoch: 200	train loss: 0.105 	train accuracy: 99.148%
# 		test loss:  0.094 	test accuracy:  93.750%
#
# epoch: 250	train loss: 0.026 	train accuracy: 100.000%
# 		test loss:  0.057 	test accuracy:  94.318%
#
# epoch: 300	train loss: 0.011 	train accuracy: 100.000%
# 		test loss:  0.040 	test accuracy:  94.886%
#
# epoch: 350	train loss: 0.007 	train accuracy: 100.000%
# 		test loss:  0.032 	test accuracy:  94.886%
#
# epoch: 400	train loss: 0.005 	train accuracy: 100.000%
# 		test loss:  0.028 	test accuracy:  94.886%
#
# epoch: 450	train loss: 0.004 	train accuracy: 100.000%
# 		test loss:  0.025 	test accuracy:  94.886%
#
# epoch: 500	train loss: 0.003 	train accuracy: 100.000%
# 		test loss:  0.023 	test accuracy:  94.886%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.227 	test accuracy:  94.318%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.250 	test accuracy:  94.318%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.265 	test accuracy:  94.318%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.277 	test accuracy:  94.318%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.286 	test accuracy:  94.318%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.293 	test accuracy:  94.318%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.300 	test accuracy:  94.318%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.306 	test accuracy:  94.318%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.311 	test accuracy:  94.318%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.316 	test accuracy:  94.318%
#
# epoch: 50	train loss: 0.225 	train accuracy: 94.034%
# 		test loss:  0.248 	test accuracy:  86.932%
#
# epoch: 100	train loss: 0.013 	train accuracy: 100.000%
# 		test loss:  0.061 	test accuracy:  94.886%
#
# epoch: 150	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.032 	test accuracy:  94.886%
#
# epoch: 200	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.023 	test accuracy:  94.886%
#
# epoch: 250	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.019 	test accuracy:  94.886%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.017 	test accuracy:  94.886%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.016 	test accuracy:  94.886%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.015 	test accuracy:  94.886%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.014 	test accuracy:  94.886%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.013 	test accuracy:  94.886%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.100 	test accuracy:  93.182%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.225 	test accuracy:  92.614%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.358 	test accuracy:  92.614%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.426 	test accuracy:  93.182%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.495 	test accuracy:  93.182%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.575 	test accuracy:  93.182%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.623 	test accuracy:  93.182%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.646 	test accuracy:  93.182%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.671 	test accuracy:  93.182%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.697 	test accuracy:  93.182%
#
# epoch: 50	train loss: 0.083 	train accuracy: 97.443%
# 		test loss:  0.195 	test accuracy:  91.477%
#
# epoch: 100	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.071 	test accuracy:  96.023%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.034 	test accuracy:  96.023%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.029 	test accuracy:  96.591%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.026 	test accuracy:  96.591%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.025 	test accuracy:  96.591%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.024 	test accuracy:  96.591%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.023 	test accuracy:  96.591%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.023 	test accuracy:  96.591%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.022 	test accuracy:  96.591%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.973 	test accuracy:  93.182%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.001 	test accuracy:  93.182%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.017 	test accuracy:  92.614%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.029 	test accuracy:  92.614%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.040 	test accuracy:  92.614%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.049 	test accuracy:  93.182%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.058 	test accuracy:  92.614%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.067 	test accuracy:  92.614%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.075 	test accuracy:  92.614%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.083 	test accuracy:  92.614%
#
# epoch: 50	train loss: 0.531 	train accuracy: 96.875%
# 		test loss:  0.674 	test accuracy:  84.659%
#
# epoch: 100	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.078 	test accuracy:  94.886%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.027 	test accuracy:  96.591%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.023 	test accuracy:  96.591%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.021 	test accuracy:  96.591%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.020 	test accuracy:  96.591%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.019 	test accuracy:  96.591%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.018 	test accuracy:  96.591%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.018 	test accuracy:  96.591%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.017 	test accuracy:  96.591%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.106 	test accuracy:  94.318%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.112 	test accuracy:  94.318%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.122 	test accuracy:  94.318%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.126 	test accuracy:  94.318%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.137 	test accuracy:  94.318%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.145 	test accuracy:  94.318%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.150 	test accuracy:  94.318%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.156 	test accuracy:  94.318%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.160 	test accuracy:  94.318%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.164 	test accuracy:  94.318%
#
# epoch: 50	train loss: 0.708 	train accuracy: 58.523%
# 		test loss:  0.658 	test accuracy:  53.977%
#
# epoch: 100	train loss: 0.677 	train accuracy: 54.830%
# 		test loss:  0.642 	test accuracy:  53.409%
#
# epoch: 150	train loss: 0.652 	train accuracy: 55.682%
# 		test loss:  0.623 	test accuracy:  53.977%
#
# epoch: 200	train loss: 0.625 	train accuracy: 69.034%
# 		test loss:  0.600 	test accuracy:  70.455%
#
# epoch: 250	train loss: 0.591 	train accuracy: 76.420%
# 		test loss:  0.570 	test accuracy:  76.705%
#
# epoch: 300	train loss: 0.547 	train accuracy: 77.273%
# 		test loss:  0.531 	test accuracy:  77.273%
#
# epoch: 350	train loss: 0.495 	train accuracy: 81.250%
# 		test loss:  0.483 	test accuracy:  80.682%
#
# epoch: 400	train loss: 0.442 	train accuracy: 84.943%
# 		test loss:  0.434 	test accuracy:  85.227%
#
# epoch: 450	train loss: 0.394 	train accuracy: 86.648%
# 		test loss:  0.387 	test accuracy:  87.500%
#
# epoch: 500	train loss: 0.352 	train accuracy: 87.500%
# 		test loss:  0.342 	test accuracy:  88.636%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.210 	test accuracy:  94.886%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.235 	test accuracy:  94.886%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.245 	test accuracy:  94.886%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.246 	test accuracy:  94.886%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.247 	test accuracy:  94.886%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.248 	test accuracy:  94.886%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.249 	test accuracy:  94.886%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.250 	test accuracy:  94.886%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.251 	test accuracy:  94.886%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.253 	test accuracy:  94.886%
#
# epoch: 50	train loss: 0.677 	train accuracy: 54.830%
# 		test loss:  0.642 	test accuracy:  53.409%
#
# epoch: 100	train loss: 0.625 	train accuracy: 68.750%
# 		test loss:  0.600 	test accuracy:  69.886%
#
# epoch: 150	train loss: 0.549 	train accuracy: 77.273%
# 		test loss:  0.532 	test accuracy:  77.273%
#
# epoch: 200	train loss: 0.444 	train accuracy: 84.659%
# 		test loss:  0.436 	test accuracy:  85.227%
#
# epoch: 250	train loss: 0.355 	train accuracy: 87.500%
# 		test loss:  0.344 	test accuracy:  88.636%
#
# epoch: 300	train loss: 0.289 	train accuracy: 91.477%
# 		test loss:  0.276 	test accuracy:  89.773%
#
# epoch: 350	train loss: 0.223 	train accuracy: 94.602%
# 		test loss:  0.221 	test accuracy:  92.045%
#
# epoch: 400	train loss: 0.181 	train accuracy: 96.023%
# 		test loss:  0.182 	test accuracy:  94.318%
#
# epoch: 450	train loss: 0.148 	train accuracy: 97.727%
# 		test loss:  0.151 	test accuracy:  93.182%
#
# epoch: 500	train loss: 0.122 	train accuracy: 98.295%
# 		test loss:  0.124 	test accuracy:  93.182%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.460 	test accuracy:  94.886%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.450 	test accuracy:  95.455%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.454 	test accuracy:  95.455%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.458 	test accuracy:  95.455%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.462 	test accuracy:  95.455%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.465 	test accuracy:  94.886%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.469 	test accuracy:  94.886%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.473 	test accuracy:  94.886%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.477 	test accuracy:  94.886%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.480 	test accuracy:  94.886%
#
# epoch: 50	train loss: 0.653 	train accuracy: 55.398%
# 		test loss:  0.623 	test accuracy:  53.977%
#
# epoch: 100	train loss: 0.549 	train accuracy: 77.273%
# 		test loss:  0.532 	test accuracy:  77.273%
#
# epoch: 150	train loss: 0.398 	train accuracy: 86.364%
# 		test loss:  0.389 	test accuracy:  86.932%
#
# epoch: 200	train loss: 0.293 	train accuracy: 91.193%
# 		test loss:  0.279 	test accuracy:  90.909%
#
# epoch: 250	train loss: 0.211 	train accuracy: 94.602%
# 		test loss:  0.205 	test accuracy:  93.750%
#
# epoch: 300	train loss: 0.157 	train accuracy: 96.875%
# 		test loss:  0.156 	test accuracy:  93.182%
#
# epoch: 350	train loss: 0.113 	train accuracy: 98.580%
# 		test loss:  0.116 	test accuracy:  93.182%
#
# epoch: 400	train loss: 0.083 	train accuracy: 99.432%
# 		test loss:  0.087 	test accuracy:  93.750%
#
# epoch: 450	train loss: 0.053 	train accuracy: 99.432%
# 		test loss:  0.069 	test accuracy:  94.886%
#
# epoch: 500	train loss: 0.029 	train accuracy: 100.000%
# 		test loss:  0.057 	test accuracy:  94.886%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.421 	test accuracy:  93.750%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.448 	test accuracy:  93.182%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.466 	test accuracy:  93.182%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.480 	test accuracy:  93.182%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.490 	test accuracy:  93.182%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.499 	test accuracy:  93.182%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.506 	test accuracy:  93.182%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.513 	test accuracy:  93.182%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.519 	test accuracy:  93.182%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.524 	test accuracy:  93.182%
#
# epoch: 50	train loss: 0.369 	train accuracy: 88.068%
# 		test loss:  0.358 	test accuracy:  86.932%
#
# epoch: 100	train loss: 0.172 	train accuracy: 95.739%
# 		test loss:  0.174 	test accuracy:  92.614%
#
# epoch: 150	train loss: 0.212 	train accuracy: 90.625%
# 		test loss:  0.190 	test accuracy:  92.045%
#
# epoch: 200	train loss: 0.020 	train accuracy: 100.000%
# 		test loss:  0.051 	test accuracy:  94.886%
#
# epoch: 250	train loss: 0.007 	train accuracy: 100.000%
# 		test loss:  0.032 	test accuracy:  94.886%
#
# epoch: 300	train loss: 0.004 	train accuracy: 100.000%
# 		test loss:  0.024 	test accuracy:  95.455%
#
# epoch: 350	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.019 	test accuracy:  95.455%
#
# epoch: 400	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.016 	test accuracy:  95.455%
#
# epoch: 450	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.015 	test accuracy:  96.023%
#
# epoch: 500	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.013 	test accuracy:  96.023%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.392 	test accuracy:  89.773%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.393 	test accuracy:  89.773%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.396 	test accuracy:  90.341%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.399 	test accuracy:  90.341%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.402 	test accuracy:  90.341%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.405 	test accuracy:  89.773%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.408 	test accuracy:  89.773%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.411 	test accuracy:  89.773%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.414 	test accuracy:  89.773%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.417 	test accuracy:  89.773%
#
# epoch: 50	train loss: 0.221 	train accuracy: 94.034%
# 		test loss:  0.315 	test accuracy:  84.659%
#
# epoch: 100	train loss: 0.203 	train accuracy: 84.943%
# 		test loss:  0.136 	test accuracy:  94.886%
#
# epoch: 150	train loss: 0.084 	train accuracy: 97.159%
# 		test loss:  0.102 	test accuracy:  95.455%
#
# epoch: 200	train loss: 0.005 	train accuracy: 100.000%
# 		test loss:  0.033 	test accuracy:  97.159%
#
# epoch: 250	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.025 	test accuracy:  97.159%
#
# epoch: 300	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.021 	test accuracy:  97.159%
#
# epoch: 350	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.019 	test accuracy:  97.159%
#
# epoch: 400	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.017 	test accuracy:  97.159%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.016 	test accuracy:  97.159%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.015 	test accuracy:  97.159%
#
# epoch: 50	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.620 	test accuracy:  92.045%
#
# epoch: 100	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.665 	test accuracy:  92.045%
#
# epoch: 150	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.889 	test accuracy:  92.045%
#
# epoch: 200	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.982 	test accuracy:  92.045%
#
# epoch: 250	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.036 	test accuracy:  92.045%
#
# epoch: 300	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.074 	test accuracy:  92.045%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.105 	test accuracy:  92.045%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.131 	test accuracy:  92.045%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.154 	test accuracy:  92.045%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  1.174 	test accuracy:  92.045%
#
# epoch: 50	train loss: 0.223 	train accuracy: 92.614%
# 		test loss:  0.223 	test accuracy:  92.045%
#
# epoch: 100	train loss: 0.250 	train accuracy: 94.602%
# 		test loss:  0.436 	test accuracy:  86.364%
#
# epoch: 150	train loss: 0.097 	train accuracy: 99.716%
# 		test loss:  0.160 	test accuracy:  92.614%
#
# epoch: 200	train loss: 0.010 	train accuracy: 100.000%
# 		test loss:  0.038 	test accuracy:  96.591%
#
# epoch: 250	train loss: 0.002 	train accuracy: 100.000%
# 		test loss:  0.017 	test accuracy:  96.023%
#
# epoch: 300	train loss: 0.001 	train accuracy: 100.000%
# 		test loss:  0.013 	test accuracy:  96.591%
#
# epoch: 350	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.011 	test accuracy:  96.591%
#
# epoch: 400	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.010 	test accuracy:  96.591%
#
# epoch: 450	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.010 	test accuracy:  96.591%
#
# epoch: 500	train loss: 0.000 	train accuracy: 100.000%
# 		test loss:  0.009 	test accuracy:  96.591%

# %%
max_id
# Out:
# [16, 0.01, torch.optim.sgd.SGD]
